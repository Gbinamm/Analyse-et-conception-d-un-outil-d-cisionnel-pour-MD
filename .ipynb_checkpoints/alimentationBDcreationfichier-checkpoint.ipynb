# %%
import pandas as pd
from sqlalchemy import create_engine, text

DB_CONFIG = {
    "dbname": "postgres",           
    "user": "postgres.hadygnmrwynnrlsekrwd", # ID Projet inclus pour le pooler
    "password": "GabinBase2026",             # Votre mot de passe réinitialisé
    "host": "aws-1-eu-west-1.pooler.supabase.com", 
    "port": "6543" 
}


FILE_PATH = "data_sensible/24 12 Mais.Droit STATS 2024.xlsx"
MOIS_SHEETS = ['Jan', 'Fev', 'Mar', 'Avr', 'Mai', 'Juin', 'Juil', 'Aoû', 'Sep', 'Oct', 'Nov', 'Déc']

def vider_tables_supabase(engine):
    """Vide les tables pour repartir de zéro."""
    print("--- NETTOYAGE DE LA BASE SUPABASE ---")
    with engine.begin() as conn:
        # TRUNCATE vide les tables et CASCADE s'occupe de supprimer les liens de clés étrangères
        conn.execute(text("TRUNCATE TABLE entretien, demande, solution RESTART IDENTITY CASCADE;"))
    print(" [OK] Tables vidées avec succès.\n")

def alimenter_bd_supabase():
    # Création de l'engine pour Supabase
    conn_url = f"postgresql://{DB_CONFIG['user']}:{DB_CONFIG['password']}@{DB_CONFIG['host']}:{DB_CONFIG['port']}/{DB_CONFIG['database']}"
    engine = create_engine(conn_url)
    
    # 1. Vidage de la base au préalable
    vider_tables_supabase(engine)

    print("--- DÉBUT DE L'ALIMENTATION SUPABASE ---")

    for idx, sheet_name in enumerate(MOIS_SHEETS, 1):
        try:
            # Lecture de l'onglet
            df = pd.read_excel(FILE_PATH, sheet_name=sheet_name)
            
            # Nettoyage initial du N°
            df['N°'] = pd.to_numeric(df['N°'], errors='coerce')
            df = df.dropna(subset=['N°'])
            df['N°'] = df['N°'].astype(int)

            # Suppression des doublons internes à l'Excel
            df = df.drop_duplicates(subset=['N°'], keep='first')

            # Tri et nettoyage Partenaire
            df = df.sort_values(by='N°')
            if 'Partenaire' in df.columns:
                df['Partenaire'] = df['Partenaire'].astype(str).replace(['nan', 'NaN', 'None', '', ' '], None)
                df['Partenaire'] = df['Partenaire'].where(pd.notnull(df['Partenaire']), None)

            # --- INSERTION DES DONNÉES ---
            
            # Insertion Entretien
            df_ent = pd.DataFrame()
            df_ent['num'] = df['N°']
            df_ent['date_ent'] = pd.to_datetime(f'2024-{idx:02d}-01')
            df_ent['mode'] = pd.to_numeric(df['Mode'], errors='coerce')
            df_ent['duree'] = pd.to_numeric(df['Durée'], errors='coerce')
            df_ent['sexe'] = pd.to_numeric(df['Sexe'], errors='coerce')
            df_ent['age'] = pd.to_numeric(df['Age'], errors='coerce')
            df_ent['vient_pr'] = pd.to_numeric(df['Vient pr'], errors='coerce')
            df_ent['sit_fam'] = df['Sit° Fam'].astype(str)
            df_ent['enfant'] = pd.to_numeric(df['Enfts'], errors='coerce')
            df_ent['modele_fam'] = pd.to_numeric(df['Modèle fam.'], errors='coerce')
            df_ent['profession'] = pd.to_numeric(df['Prof°'], errors='coerce')
            df_ent['ress'] = pd.to_numeric(df['Ress. 1'], errors='coerce')
            df_ent['origine'] = df['Origine'].astype(str)
            df_ent['commune'] = df['Domicile'].astype(str)
            df_ent['partenaire'] = df['Partenaire']

            df_ent.to_sql('entretien', engine, if_exists='append', index=False)

            # Insertion Demande et Solution
            alimenter_table_liee(df, engine, 'demande', ['Dem.1', 'Dem.2', 'Dem.3'])
            alimenter_table_liee(df, engine, 'solution', ['Sol.1', 'Sol.2', 'Sol.3'])

            print(f" [OK] {sheet_name} transféré vers Supabase.")

        except Exception as e:
            print(f" [ERREUR] {sheet_name} : {e}")

    # Synchronisation finale de la séquence (important pour éviter les erreurs d'ID plus tard)
    with engine.begin() as conn:
        conn.execute(text("SELECT setval('entretien_num_seq', (SELECT MAX(num) FROM entretien))"))
    
    print("\n--- TERMINÉ : SUPABASE EST À JOUR ---")

def alimenter_table_liee(df_source, engine, table_nom, colonnes_excel):
    lignes = []
    for _, row in df_source.iterrows():
        for i, col in enumerate(colonnes_excel, 1):
            val = row.get(col)
            if pd.notna(val) and str(val).strip() not in ["", "nan", "NaN", "None"]:
                lignes.append({'num': int(row['N°']), 'pos': i, 'nature': str(val).strip()})
    if lignes:
        pd.DataFrame(lignes).to_sql(table_nom, engine, if_exists='append', index=False)

if __name__ == "__main__":
    alimenter_bd_supabase()
# Out:
# --- NETTOYAGE DE LA BASE SUPABASE ---
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:3280, in Engine._wrap_pool_connect(self, fn, connection)
#    3279 try:
# -> 3280     return fn()
#    3281 except dialect.dbapi.Error as e:
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:310, in Pool.connect(self)
#     303 """Return a DBAPI connection from the pool.
#     304
#     305 The connection is instrumented such that when its
#    (...)
#     308
#     309 """
# --> 310 return _ConnectionFairy._checkout(self)
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     867 if not fairy:
# --> 868     fairy = _ConnectionRecord.checkout(pool)
#     870     fairy._pool = pool
#
# ...
